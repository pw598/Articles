# %% [markdown]
# # Probability IV
# # Bayesian Inference

# %% [markdown]
# Moved To: <a href="https://nbviewer.org/github/pw598/Articles/blob/main/Probability%20III%20-%20Bayesian_Inference.ipynb">Probability III - Bayesian Inference</a>
